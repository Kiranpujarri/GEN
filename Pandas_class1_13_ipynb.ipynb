# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame([1,2,3],columns=['number'],index=[2,3,4])
# Out:
#    number
# 2       1
# 3       2
# 4       3

# %%
df=pd.DataFrame(np.random.randint(0,100,(3,3)),columns="A B C".split(),index="P Q R".split())

# %%
df
# Out:
#     A   B   C
# P  99  89   4
# Q  51  38   9
# R  41  62  30

# %%
df=pd.DataFrame(np.random.randint(0,100,(10,5)))

# %%
data=[]
for i in range(1,11):
  data.append("student"+str(i))

# %%
data
# Out:
# ['student1',
#  'student2',
#  'student3',
#  'student4',
#  'student5',
#  'student6',
#  'student7',
#  'student8',
#  'student9',
#  'student10']

# %%
df.index=data

# %%
df
# Out:
#             0   1   2   3   4
# student1   32  48  10  69  17
# student2   45  63  98  51  69
# student3   83  38  81  64  43
# student4   67   8   2  46  78
# student5   65  86  93  67  32
# student6   63   7   5  58  24
# student7   63   7  29  15  22
# student8   91  67   0  61  21
# student9   71  99   6  79  73
# student10  26  26  43  40  57

# %%
data=[]
for i in range(1,6):
  data.append("subject"+str(i))

# %%
df.columns=data

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1         32        48        10        69        17
# student2         45        63        98        51        69
# student3         83        38        81        64        43
# student4         67         8         2        46        78
# student5         65        86        93        67        32
# student6         63         7         5        58        24
# student7         63         7        29        15        22
# student8         91        67         0        61        21
# student9         71        99         6        79        73
# student10        26        26        43        40        57

# %%
df.index
# Out:
# Index(['student1', 'student2', 'student3', 'student4', 'student5', 'student6',
#        'student7', 'student8', 'student9', 'student10'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['subject1', 'subject2', 'subject3', 'subject4', 'subject5'], dtype='object')

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1         32        48        10        69        17
# student2         45        63        98        51        69
# student3         83        38        81        64        43
# student4         67         8         2        46        78
# student5         65        86        93        67        32
# student6         63         7         5        58        24
# student7         63         7        29        15        22
# student8         91        67         0        61        21
# student9         71        99         6        79        73
# student10        26        26        43        40        57

# %%
df.shape
# Out:
# (10, 5)

# %%
df.values
# Out:
# array([[32, 48, 10, 69, 17],
#        [45, 63, 98, 51, 69],
#        [83, 38, 81, 64, 43],
#        [67,  8,  2, 46, 78],
#        [65, 86, 93, 67, 32],
#        [63,  7,  5, 58, 24],
#        [63,  7, 29, 15, 22],
#        [91, 67,  0, 61, 21],
#        [71, 99,  6, 79, 73],
#        [26, 26, 43, 40, 57]])

# %%
df.dtypes
# Out:
# subject1    int64
# subject2    int64
# subject3    int64
# subject4    int64
# subject5    int64
# dtype: object

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1         32        48        10        69        17
# student2         45        63        98        51        69
# student3         83        38        81        64        43
# student4         67         8         2        46        78
# student5         65        86        93        67        32
# student6         63         7         5        58        24
# student7         63         7        29        15        22
# student8         91        67         0        61        21
# student9         71        99         6        79        73
# student10        26        26        43        40        57

# %%
df.iloc[:3,-3:]
# Out:
#           subject3  subject4  subject5
# student1        10        69        17
# student2        98        51        69
# student3        81        64        43

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5
# student1         32        48        10        69        17
# student2         45        63        98        51        69
# student3         83        38        81        64        43
# student4         67         8         2        46        78
# student5         65        86        93        67        32
# student6         63         7         5        58        24
# student7         63         7        29        15        22
# student8         91        67         0        61        21
# student9         71        99         6        79        73
# student10        26        26        43        40        57

# %%
df.iloc[0:4,0:4]
# Out:
#           subject1  subject2  subject3  subject4
# student1        32        48        10        69
# student2        45        63        98        51
# student3        83        38        81        64
# student4        67         8         2        46

# %%
df.loc["student1":"student4","subject1":"subject4"]
# Out:
#           subject1  subject2  subject3  subject4
# student1        32        48        10        69
# student2        45        63        98        51
# student3        83        38        81        64
# student4        67         8         2        46

# %%
df["student1":"student2"]['subject1']
# Out:
# student1    32
# student2    45
# Name: subject1, dtype: int64

# %%
df=pd.read_excel("/content/Sample - Superstore.xls")

# %%
df.shape

# %%
df.columns

# %%
df[df['Segment']=='Consumer']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Segment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-32-2844005001.py in <cell line: 0>()
# ----> 1 df[df['Segment']=='Consumer']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Segment'

# %%
data=np.random.randint(0,10,10)

# %%
data

# %%
data[data<5]
# Out:
# array([2, 2, 1, 0, 1])

# %%
df[(df['Region']=='West') | (df['Category']=='Office Supplies')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-35-1048204026.py in <cell line: 0>()
# ----> 1 df[(df['Region']=='West') | (df['Category']=='Office Supplies')]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Region'

# %%
df.dtypes
# Out:
# subject1    int64
# subject2    int64
# subject3    int64
# subject4    int64
# subject5    int64
# dtype: object

# %%
df.select_dtypes(include='float').mean()
# Out:
# Series([], dtype: float64)

# %%
df.select_dtypes(include='float').std()
# Out:
# Series([], dtype: float64)

# %%
df.columns
# Out:
# Index(['subject1', 'subject2', 'subject3', 'subject4', 'subject5'], dtype='object')

# %%
import pandas as pd
import numpy as np

# %%
  #pandas class 1
