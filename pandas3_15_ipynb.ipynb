# %%
import pandas as pd
df=pd.read_excel("/content/sample/Superstore Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-6-557448942.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_excel("/content/sample/Superstore Dataset.csv")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/Superstore Dataset.csv")

# %%
df.dtypes
# Out:
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
import numpy as np
np.iinfo(np.int8).min
# Out:
# -128

# %%
np.iinfo(np.int8).max
# Out:
# 127

# %%
np.finfo(np.float16).max
# Out:
# np.float16(65500.0)

# %%
int : -128 to 127
uint : unsigned integer (0 to 255)    #sample
# Out:
#   File "/tmp/ipython-input-12-909673941.py", line 1
#     int : -128 to 127
#                ^
# SyntaxError: invalid syntax

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
32768+32767   #unit16
# Out:
# 65535

# %%
df.shape
# Out:
# (9994, 20)

# %%
df.iloc[0:5,:]cc
# Out:
#   File "/tmp/ipython-input-21-2806668199.py", line 1
#     df.iloc[0:5,:]cc
#                   ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
sample=df['City'].head(10)

# %%
pd.get_dummies(sample)
# Out:
#    Athens  Henderson  Houston  Naperville  Philadelphia
# 0   False      False     True       False         False
# 1   False      False    False        True         False
# 2   False      False    False        True         False
# 3   False      False    False        True         False
# 4   False      False    False       False          True
# 5   False       True    False       False         False
# 6   False       True    False       False         False
# 7   False       True    False       False         False
# 8    True      False    False       False         False
# 9   False       True    False       False         False

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 20)

# %%
df['Region'].nunique()  #it show unique numbers mean how many types
# Out:
# 4

# %%
df['Region'].value_counts() #4count which all
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df['Region'].value_counts(normalize=True)*100
# Out:
# Region
# West       32.049230
# East       28.497098
# Central    23.243946
# South      16.209726
# Name: proportion, dtype: float64

# %%
sorted_values=df['Sales'].sort_values(ascending=False)
sorted_values.iloc[2,]
# Out:
# np.float64(13999.96)

# %%
sorted_values
# Out:
# 212     22638.480
# 5773    17499.950
# 7104    13999.960
# 8986    11199.968
# 9334    10499.970
#           ...
# 1199        0.876
# 278         0.852
# 4968        0.836
# 6950        0.556
# 7781        0.444
# Name: Sales, Length: 9994, dtype: float64

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800  2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326  2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817  2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...         ...         ...             ...         ...
# 9989  CA-2022-156720  2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427  2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259  2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
(df[['Region',"Sales",'Category']].groupby(["Region",'Category']).sum()/df['Sales'].sum())*100
# Out:
#                              Sales
# Region  Category
# Central Furniture         7.130294
#         Office Supplies   7.270867
#         Technology        7.418433
# East    Furniture         9.067174
#         Office Supplies   8.946369
#         Technology       11.534646
# South   Furniture         5.106157
#         Office Supplies   5.469757
#         Technology        6.476226
# West    Furniture        10.996546
#         Office Supplies   9.614016
#         Technology       10.969517

# %%
df_grouped = df.groupby(['Region', 'Category'])['Sales'].sum().reset_index()
df_grouped['Sales_Percentage'] = (df_grouped['Sales'] / df_grouped['Sales'].sum() * 100).round(2)
print(df_grouped)
# Out:
#      Region         Category        Sales  Sales_Percentage
# 0   Central        Furniture  163797.1638              7.13
# 1   Central  Office Supplies  167026.4150              7.27
# 2   Central       Technology  170416.3120              7.42
# 3      East        Furniture  208291.2040              9.07
# 4      East  Office Supplies  205516.0550              8.95
# 5      East       Technology  264973.9810             11.53
# 6     South        Furniture  117298.6840              5.11
# 7     South  Office Supplies  125651.3130              5.47
# 8     South       Technology  148771.9080              6.48
# 9      West        Furniture  252612.7435             11.00
# 10     West  Office Supplies  220853.2490              9.61
# 11     West       Technology  251991.8320             10.97

# %%
pd.pivot_table(df,values='Profit',index='Category',aggfunc=np.mean)
# Out:
#                     Profit
# Category
# Furniture         8.699327
# Office Supplies  20.327050
# Technology       78.752002

# %%
pivot = df.pivot_table(values='Profit', index='Category', aggfunc='mean')
print(pivot)
# Out:
#                     Profit
# Category
# Furniture         8.699327
# Office Supplies  20.327050
# Technology       78.752002

# %%
summary = df.pivot_table(values=['Sales', 'Profit'], index=['Category', 'Sub-Category'], aggfunc='sum')
print(summary)
# Out:
#                                   Profit        Sales
# Category        Sub-Category
# Furniture       Bookcases     -3472.5560  114879.9963
#                 Chairs        26590.1663  328449.1030
#                 Furnishings   13059.1436   91705.1640
#                 Tables       -17725.4811  206965.5320
# Office Supplies Appliances    18138.0054  107532.1610
#                 Art            6527.7870   27118.7920
#                 Binders       30221.7633  203412.7330
#                 Envelopes      6964.1767   16476.4020
#                 Fasteners       949.5182    3024.2800
#                 Labels         5546.2540   12486.3120
#                 Paper         34053.5693   78479.2060
#                 Storage       21278.8264  223843.6080
#                 Supplies      -1189.0995   46673.5380
# Technology      Accessories   41936.6357  167380.3180
#                 Copiers       55617.8249  149528.0300
#                 Machines       3384.7569  189238.6310
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# Total Sales by Category and Sub-Category with Grand Totals
pivot_table = pd.pivot_table(df,
                              values='Sales',
                              index=['Category', 'Sub-Category'],
                              aggfunc='sum',
                              margins=True,
                              margins_name='Grand Total')
pivot_table
# Out:
#                                   Sales
# Category        Sub-Category
# Furniture       Bookcases     114880.00
#                 Chairs        328449.10
#                 Furnishings    91705.16
#                 Tables        206965.53
# Office Supplies Appliances    107532.16
#                 Art            27118.79
#                 Binders       203412.73
#                 Envelopes      16476.40
#                 Fasteners       3024.28
#                 Labels         12486.31
#                 Paper          78479.21
#                 Storage       223843.61
#                 Supplies       46673.54
# Technology      Accessories   167380.32
#                 Copiers       149528.03
#                 Machines      189238.63
#                 Phones        330007.05
# Grand Total                  2297200.86

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
avg_daily_sales = df.groupby(['Category', 'Sub-Category', 'Order Date'])['Sales'].sum().groupby(['Category', 'Sub-Category']).mean().reset_index(name='Avg_Daily_Sales')
print(avg_daily_sales)
# Out:
#            Category Sub-Category  Avg_Daily_Sales
# 0         Furniture    Bookcases           574.40
# 1         Furniture       Chairs           789.54
# 2         Furniture  Furnishings           153.10
# 3         Furniture       Tables           805.31
# 4   Office Supplies   Appliances           293.80
# 5   Office Supplies          Art            51.17
# 6   Office Supplies      Binders           262.13
# 7   Office Supplies    Envelopes            75.58
# 8   Office Supplies    Fasteners            15.43
# 9   Office Supplies       Labels            43.06
# 10  Office Supplies        Paper           107.51
# 11  Office Supplies      Storage           401.15
# 12  Office Supplies     Supplies           271.36
# 13       Technology  Accessories           326.91
# 14       Technology      Copiers          2231.76
# 15       Technology     Machines          1819.60
# 16       Technology       Phones           576.94

# %%
from tempfile import SpooledTemporaryFile
monthly sales profits
eachproduct vs quantity
sales according to the region
top selling products
delay between order date and shippmenet date

# %%
# imp questions =# Superstore Dataset - EDA and Hypothesis Questions
# Exploratory Data Analysis (EDA) Questions
# Sales & Profit Trends

# What is the overall trend of sales and profit over time?
# Which months or years have the highest sales?
# How do sales and profit vary by region?
# What is the average discount offered per region?
# Which states generate the highest profit?
# Are there any states consistently giving losses?
# What is the profit margin by product category?
# What is the correlation between discount and profit?
# What is the average order value?
# How do sales differ across segments?
# Product Performance
# Which products have the highest sales?
# Which products are the most profitable?
# Which sub-categories have the lowest performance?
# What is the distribution of sales across categories?
# What is the average discount per sub-category?
# Are some products over-discounted and yielding loss?
# What is the reorder frequency of popular items?
# Are certain products only sold in certain regions?
# Customer Analysis
# Who are the top 10 customers by lifetime value?
# What is the average order size per customer?
# What segment of customers orders the most frequently?
# Are there loyal customers (repeat buyers)?
# What’s the average time between customer orders?
# Order Date & Shipping Analysis
# Which days of the week get more orders?
# What is the average shipping delay across regions?
# Does ship mode affect delivery time?
# Is there seasonality in sales (e.g., November spike)?
# Are holiday seasons associated with more discounts?
# Geographical Insights
# What is the sales and profit distribution by city?
# Which postal codes have the highest orders?
# Which regions are underperforming despite high sales?
# Are there cities where we’re giving too much discount?
# Inventory & Quantity Patterns
# What is the average quantity ordered per product?
# Do high-quantity orders lead to losses?
# Which sub-categories are mostly ordered in bulk?
# Hypothesis Testing Questions
# Category & Discount
# Does increasing discount increase sales?
# Does high discount lead to negative profit?
# Is the average discount significantly different between categories?
# Do discounts significantly affect the number of items ordered?
# Region-Based Hypothesis
# Do sales in the West region differ significantly from the East?
# Is customer behavior (e.g., quantity ordered) the same across all regions?
# Segment Comparisons
# Does the consumer segment generate more profit than corporate?
# Is the average order value different between home office and consumer?
# Shipping Mode Analysis
# Does Standard Class have more late deliveries than First Class?
# Is there a significant difference in profit between different ship modes?
# Time-Based Testing
# Has average monthly profit increased over the last 3 years?
# Do weekends see more orders than weekdays?
# Product & Location
# Are some products significantly more popular in certain regions?
# Do sub-categories perform differently in different states?
# Profitability Check
# Are there products that are consistently unprofitable?

# [ ]

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
trend = df.groupby('Order Date')[['Sales', 'Profit']].sum()
trend.plot(title='Sales & Profit Over Time')
# Out:
# <Axes: title={'center': 'Sales & Profit Over Time'}, xlabel='Order Date'>

# %%
Lines = [
    "Superstore Dataset - EDA and Hypothesis Questions",


    "Are there products that are consistently unprofitable?",
]

for i, line in enumerate(Lines, start=1):   # this code writ for setting order the senyence
    print(f"{i}. {line}")
# Out:
# 1. Superstore Dataset - EDA and Hypothesis Questions
# 2. Are there products that are consistently unprofitable?

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2019-103800 2019-01-03  2019-01-07  Standard Class    DP-13000
# 1     CA-2019-112326 2019-01-04  2019-01-08  Standard Class    PO-19195
# 2     CA-2019-112326 2019-01-04  2019-01-08  Standard Class    PO-19195
# 3     CA-2019-112326 2019-01-04  2019-01-08  Standard Class    PO-19195
# 4     CA-2019-141817 2019-01-05  2019-01-12  Standard Class    MB-18085
# ...              ...        ...         ...             ...         ...
# 9989  CA-2022-156720 2022-12-30  2023-01-03  Standard Class    JM-15580
# 9990  CA-2022-143259 2022-12-30  2023-01-03  Standard Class    PO-18865
# 9991  CA-2022-143259 2022-12-30  2023-01-03  Standard Class    PO-18865
# 9992  CA-2022-115427 2022-12-30  2023-01-03  Standard Class    EB-13975
# 9993  CA-2022-143259 2022-12-30  2023-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# ...

# %%
top_products = df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False)
print(top_products.head(10))  # Top 10 most profitable products
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                         25199.93
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    7753.04
# Hewlett Packard LaserJet 3310 Copier                                           6983.88
# Canon PC1060 Personal Laser Copier                                             4570.93
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      4094.98
# Ativa V4110MDD Micro-Cut Shredder                                              3772.95
# 3D Systems Cube Printer, 2nd Generation, Magenta                               3717.97
# Plantronics Savi W720 Multi-Device Wireless Headset System                     3696.28
# Ibico EPK-21 Electric Binding System                                           3345.28
# Zebra ZM400 Thermal Label Printer                                              3343.54
# Name: Profit, dtype: float64

# %%
print("done")
# Out:
# done
